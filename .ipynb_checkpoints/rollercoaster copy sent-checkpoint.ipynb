# %%
# %load_ext pycodestyle_magic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %%
df = pd.read_csv('rollercoaster.csv')
df.head()
# Out:
#                           Name                             Park   City/Region  \
# 0  10 Inversion Roller Coaster               Chimelong Paradise         Panyu
# 1                       Abismo  Parque de Atracciones de Madrid        Madrid
# 2              Adrenaline Peak              Oaks Amusement Park      Portland
# 3                    Afterburn                        Carowinds     Charlotte
# 4                   Alpengeist       Busch Gardens Williamsburg  Williamsburg
#
#       City/State/Region Country/Region Geographic Region Construction  \
# 0  Guangzhou, Guangdong          China              Asia        Steel
# 1                Madrid          Spain            Europe        Steel
# 2                Oregon  United States     North America        Steel
# 3        North Carolina  United States     North America        Steel
# 4              Virginia  United States     North America        Steel
#
#        Type      Status  Year/Date Opened Height (feet)   Speed (mph)  \
# 0  Sit Down   Operating            2006.0          98.4          45.0
# 1  Sit Down   Operating            2006.0         151.6          65.2
# 2  Sit Down  Operating             2018.0            72          45.0
# 3  Inverted   Operating            1999.0           113          62.0
# 4  Inverted   Operating            1997.0           195          67.0
#
#    Length (feet) Inversions (YES or NO)  Number of Inversions Drop (feet)  \
# 0         2788.8                    YES                  10.0         NaN
# 1         1476.4                    YES                   2.0         NaN
# 2         1050.0                    YES                   3.0         NaN
# 3         2956.0                    YES                   6.0         NaN
# 4         3828.0                    YES                   6.0         170
#
#   Duration (min:sec) G Force  Vertical Angle (degrees)
# 0               1:32     NaN                       NaN
# 1               1:00       4                       NaN
# 2                NaN     NaN                      97.0
# 3               2:47     NaN                       NaN
# 4               3:10     3.7                       NaN

# %%
# %%pycodestyle
# df.loc[134, 'Duration (sec)'] = '0:00'
# df.iloc[134]

# %% [markdown]
# Algorithm: (.5*gforce)((displacement/(2h/g*sin**2(theta))**.5)/10)(duration/ max(duration))+(speed/max(speed))+(height/(max(height))))

# %%
# %%pycodestyle
#
# import pandas as pd
# import math
#
# rollers = pd.read_csv('rollercoaster.csv')
# rollers.columns = rollers.columns.str.strip()
# rollers.columns
# rollers.head()
# rollers.at[111, 'Height (feet)'] = 200
# rollers[111:112]
# rollers['Height (feet)'] = rollers['Height (feet)'].astype(float)
# rollers = rollers.rename(columns={"Height (feet)": "Height"})
# rollers[['Name', 'Height']]
# rollers = rollers.rename(columns={"Speed (mph)": "Speed"})
# rollers[['Name', 'Speed']]
# rollers = rollers.rename(columns={"Drop (feet)": "Drop"})
# rollers = rollers.rename(columns={"Length (feet)": "Length"})
# rollers = rollers.rename(columns={"Duration (min:sec)": "Duration"})
#
#
# rollers[['Name', 'Drop']]
# print(rollers.Height.max())
# print(rollers.Speed.max())

# %%
# %%pycodestyle
# rollers.columns
#
#
# rollers['G Force'] = pd.to_numeric(rollers['G Force'], errors='coerce')
# rollers['Drop'] = pd.to_numeric(rollers['Drop'], errors='coerce')
#
# rollers['Drop'] = rollers['Drop'].fillna(1)
# rollers['G Force'] = rollers['G Force'].fillna(1)
# rollers['Vertical Angle (degrees)'] = rollers
# ['Vertical Angle (degrees)'].fillna(1)
#
# rollers['Vertical Angle (degrees)'] = rollers
# ['Vertical Angle (degrees)'].apply(math.radians)
#
#
# # rollers['Drop']
# rollers['Vertical Angle (degrees)']
# # rollers.dtypes

# %%
# %%pycodestyle
# import math
# math.sin(1)

# %%
# %%pycodestyle
# rollers['Score'] = .5*rollers
# ['G Force'] + ((rollers['Drop'] /
#                 (rollers['Vertical Angle (degrees)'].apply
#                  (math.sin))) / (2*rollers['Drop'] / 9.8 *
#                                  (rollers['Vertical Angle (degrees)'].
#                                  apply(math.sin))**2)**.5)/10.
# rollers['Score']
